# %%
# import necessary labraries 

import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset
df = pd.read_excel("C:\\Users\\admin\\Downloads\\Development and Non-Development Expenditure Aggregate Dataset.xlsx")
df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  Appendix Table 3: Development and Non-Developm...
# 1          NaN                                          (₹ Crore)
# 2          NaN                                               Year
# 3          NaN                                                  1
# 4          NaN                                            2006-07
# 5          NaN                                                NaN
# 6          NaN                                            2007-08
# 7          NaN                                                NaN
# 8          NaN                                            2008-09
# 9          NaN                                                NaN
# 10         NaN                                            2009-10
# 11         NaN                                                NaN
# 12         NaN                                            2010-11
# ...

# %%
# check data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  30 non-null     object
#  2   Unnamed: 2  42 non-null     object
#  3   Unnamed: 3  42 non-null     object
#  4   Unnamed: 4  42 non-null     object
#  5   Unnamed: 5  42 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.5+ KB

# %%
# check null values
df.isnull()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0         True       False        True        True        True        True
# 1         True       False        True        True        True        True
# 2         True       False       False       False       False       False
# 3         True       False       False       False       False       False
# 4         True       False       False       False       False       False
# 5         True        True       False       False       False       False
# 6         True       False       False       False       False       False
# 7         True        True       False       False       False       False
# 8         True       False       False       False       False       False
# 9         True        True       False       False       False       False
# 10        True       False       False       False       False       False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    50
# Unnamed: 1    20
# Unnamed: 2     8
# Unnamed: 3     8
# Unnamed: 4     8
# Unnamed: 5     8
# dtype: int64

# %%
# check nulls 
df.isnull().sum()/len(df)*100
# Out:
# Unnamed: 0    100.0
# Unnamed: 1     40.0
# Unnamed: 2     16.0
# Unnamed: 3     16.0
# Unnamed: 4     16.0
# Unnamed: 5     16.0
# dtype: float64

# %% [markdown]
# # Data Reduction

# %%
# Row 2 has proper headers, row 4 onwards has data
df = df.iloc[4:, 1:6].copy()
df.columns = ["Year", "Development", "Non_Development", "Others", "Total"]
df
# Out:
#                                                  Year Development  \
# 4                                             2006-07      392165
# 5                                                 NaN       -59.7
# 6                                             2007-08      464462
# 7                                                 NaN       -61.7
# 8                                             2008-09    567086.2
# 9                                                 NaN       -64.3
# 10                                            2009-10    637731.1
# 11                                                NaN       -62.8
# 12                                            2010-11    720354.7
# 13                                                NaN       -62.2
# 14                                            2011-12    852405.6
# 15                                                NaN       -63.1
# 16                                            2012-13    972256.5
# ...

# %%
# Convert numeric columns
for col in ["Development", "Non_Development", "Others", "Total"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
# Ensure Year is treated as string
df["Year"] = df["Year"].astype(str).str.strip()

# %%
# Reset index
df = df.reset_index(drop=True)

# %%
# Example: drop "Others" column if not needed
df_reduced = df.drop(columns=["Others"])

# %% [markdown]
# # Data Wrangling

# %%
# Fill missing values if any
df = df.fillna(0)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
print("Shape of dataset:", df.shape)
print("\nData types:\n", df.dtypes)
print("\nMissing values:\n", df.isnull().sum())
print("\nSummary statistics:\n", df.describe())
# Out:
# Shape of dataset: (46, 5)
#
# Data types:
#  Year                object
# Development        float64
# Non_Development    float64
# Others             float64
# Total              float64
# dtype: object
#
# Missing values:
#  Year               0
# Development        0
# Non_Development    0
# Others             0
# Total              0
# dtype: int64
#
# Summary statistics:
#          Development  Non_Development         Others         Total
# count  4.600000e+01     4.600000e+01      46.000000  4.600000e+01
# mean   7.725090e+05     3.431708e+05  111777.206522  1.227457e+06
# std    1.148793e+06     5.033583e+05  186420.029579  1.835407e+06
# min   -6.760000e+01    -3.220000e+01     -10.800000 -1.000000e+02
# 25%   -6.247500e+01    -2.827500e+01      -7.300000 -1.000000e+02
# 50%    0.000000e+00     0.000000e+00       0.000000  0.000000e+00
# 75%    1.263605e+06     5.509877e+05  131280.500000  1.945873e+06
# max    3.929477e+06     1.690592e+06  664229.100000  6.284299e+06

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x="Year", y="Total", marker="o")
plt.title("Total Expenditure Trend Over Years")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12480\3119863027.py:6: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df_clean, x="Year", y="Development", marker="o", label="Development")
sns.lineplot(data=df_clean, x="Year", y="Non_Development", marker="o", label="Non-Development")
plt.title("Development vs Non-Development Expenditure")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12480\3387789889.py:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
